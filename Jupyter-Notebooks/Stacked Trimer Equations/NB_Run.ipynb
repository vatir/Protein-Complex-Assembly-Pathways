# %%
# %run print_equations.py
# Out:
# Species: 1
# -6.0
# -4.0
# -3.0
# -3.0
# -2.0
# -3.0
# -2.0
# -2.0
# -3.0
# -2.0
# 1 : (0, 1) : 2.0
# 2 : (1, 0) : 2.0
# 3 : (1, 0) : 1.0
# 3 : (0, 1) : 1.0
# 4 : (1, 0) : 2.0
# 5 : (1, 0) : 1.0
# 5 : (0, 1) : 1.0
# 6 : (1, 0) : 2.0
# 7 : (1, 1) : 4.0
# 8 : (2, 0) : 3.0
# 9 : (2, 0) : 2.0
# 9 : (0, 1) : 1.0
# 10 : (2, 1) : 2.0
# 10 : (2, 0) : 1.0
# 10 : (1, 1) : 2.0
# 11 : (2, 1) : 6.0
# \DCDtNoSpacing{\species{1}} &= \kon{}(-6\Conc{\species{1}}^2-4\Conc{\species{1}}\Conc{\species{2}}-3\Conc{\species{1}}\Conc{\species{3}}-3\Conc{\species{1}}\Conc{\species{4}}-2\Conc{\species{1}}\Conc{\species{5}}-3\Conc{\species{1}}\Conc{\species{6}}-2\Conc{\species{1}}\Conc{\species{7}}\\
#  & \quad -2\Conc{\species{1}}\Conc{\species{8}}-3\Conc{\species{1}}\Conc{\species{9}}-2\Conc{\species{1}}\Conc{\species{10}}-\Conc{\species{1}}\Conc{\species{11}})+2\Conc{\species{2}}k^{eff}_{0,1}\\
# ...
