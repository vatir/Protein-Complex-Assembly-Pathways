# %%
import os
print(os.getcwd())
os.chdir('/nfs/Data/Notebooks/Inhibitors/')
# %run DataParsing.ipynb
# Out:
# /nfs/Data/Notebooks/Plotting
# /nfs/Data/Notebooks/Inhibitors
# []
# 0
# []
# CPU times: user 1.5 s, sys: 87.8 ms, total: 1.59 s
# Wall time: 2.19 s
# []
# Types: 4 : ['AA', 'AB', 'BA', 'BB']
# KDI  : 20 : [1e-10, 2.06913808111e-10, 4.28133239872e-10, 8.8586679041e-10, 1.83298071083e-09, 3.79269019073e-09, 7.84759970351e-09, 1.62377673919e-08, 3.35981828628e-08, 6.95192796178e-08, 1.43844988829e-07, 2.97635144163e-07, 6.15848211066e-07, 1.2742749857e-06, 2.63665089873e-06, 5.45559478117e-06, 1.12883789168e-05, 2.33572146909e-05, 4.83293023857e-05, 0.0001]
# I0   : 20 : [1e-08, 2.06913808111e-08, 4.28133239872e-08, 8.8586679041e-08, 1.83298071083e-07, 3.79269019073e-07, 7.84759970351e-07, 1.62377673919e-06, 3.35981828628e-06, 6.95192796178e-06, 1.43844988829e-05, 2.97635144163e-05, 6.15848211066e-05, 0.00012742749857, 0.000263665089873, 0.000545559478117, 0.00112883789168, 0.00233572146909, 0.00483293023857, 0.01]
# A0   : 1 : [4e-06]
# B0   : 1 : [4e-06]
# ...

# %%
os.chdir('/nfs/Data/Notebooks/Plotting/')

# %%
# Time Indcies: 57 90 38 99 12 60 20

# %% [raw]
# np.argmax(PossibleTimePoints > 5.e+4)
# SetTimePointForDataSets(60)

# %%
# %%time
for TP in [57, 90, 38, -1, 60, 20]:
    TimePointIndex = TP

    CurrentTimePoint = PossibleTimePoints[TimePointIndex]
    SetTimePointForDataSets(CurrentTimePoint)
    # %run InhibitorPlots.ipynb
# Out:
# Available matplotlib backends: ['osx', 'qt4', 'qt5', 'gtk3', 'notebook', 'wx', 'qt', 'nbagg', 'gtk', 'tk', 'inline']
# /nfs/Data/Notebooks/Plotting
# /nfs/Data/Notebooks/Plotting
# (-1.0, 0.27136848223435656)
# 0.271368482234 : (array([17]), array([19]))
# 0.266556539562 : (array([17]), array([19]))
# [-1.0, 0.25898016011370006]
# [-83.99995803584423, -62.999916071688475, -41.999874107532705, -20.999832143376938]
# 0.01
# 1e-10
# 0.00112883789168
# 2.33572146909e-05
# /home/vatir/anaconda3/envs/DataViewer27/lib/python2.7/site-packages/matplotlib/figure.py:397: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# /home/vatir/anaconda3/envs/DataViewer27/lib/python2.7/site-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'cursive'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
# ...
